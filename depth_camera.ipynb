# %%
import pyrealsense2 as rs
import numpy as np

# %%
# Create a context object. This object owns the handles to all connected realsense devices
pipeline = rs.pipeline()
pipeline.start()

# %%
depth = frames.get_depth_frame()

# %%
try:
    while True:
        # Create a pipeline object. This object configures the streaming camera and owns it's handle
        frames = pipeline.wait_for_frames()
        depth = frames.get_depth_frame()
        depth_data = depth.as_frame().get_data()
        np_image = np.asanyarray(depth_data)

finally:
    pipeline.stop()
# Out:
#
#
#
#
#                                                               hB
#                                                              WWW
#                                                             hWWW
#                                                             WWWW
#                                                      :BBXXXXWWWW
#                                                      WWWWWWWWWWW
#                                                     .WWWWWWWWWWW
#             hhnn                                    nWWWWWWWWWWW
#         hBhnWWWWn                                   BWWWWWWWWWWW
#        :WWWXWWWWh                                 .XWWWWWWWWWWWW
#         XWWhWWWWh                                :WXWWWWWWWWWWWW
#        BWWWBXWWWWWh                             .XhXWWWWWWWXWWWW
#        .WWWXWWWWWW:                             n.nWWWWWWWXWWWWW
#        hWWWWXWWWWWWXn..nhhh:.  .                  XWWWWXhXhWWWWW
#        hWWWWBWWXhBBWWWWWWWWWWWWWW                 hWWWXXh hXWWWW
#        hWWWWXXWWWWWWWWWWWWWWWWWWBWWWBBn.           .  :  BXWh:XW
#        WWWWWWhWWWWWWWWWWXWWWWWWWBWWWWWWWWhn          :n .:WWWnnh
#
#
#
#
#
#
#
#                                                               hB
#                                                              XWW
#                                                             nWWW
#                                                             XWWW
#                                                      :BBXXXXWWWW
#                                                      WWWWWWWWWWW
#                                                     :WWWWWWWWWWW
#             hhnn                                    :WWWWWWWWWWW
#         hBnnWWWWh                                   hWWWWWWWWWWW
#        .WWWBWWWWh                                 .XWWWWWWWWWWWW
#         WWWBWWWWh                                :WBXWWWWWWWWWWW
#        hWWWBWWWWWWh                             .XhXWWWWWWWBWWWW
#        :WWWXWWWWWW.                             : hWWWXWWWWWWWWW
#        nWWWWXWWWWWWBhn.nhhh:. ..                  XWWWWXnBhWWWWW
#        hWWWWBWWBBBhWWXWWWWWWWWWWW.                BWXXXXB nXWWWW
#        BWWWWBXWWWWWWWWWWWWWWWWWWBWWWBhn.           .  :  BXWB:XW
#        XWWWWWhXWWWWWWWWWXWWWWWXXXWWWWWWWWBn.         :h .:WWWn.n
#
#
#
#
#
#
#
#                                                               nB
#                                                              :WW
#                                                             .WWW
#                                                             nWWW
#                                                      :BXXXXXWWWW
#                                                      WWWWWWWWWWW
#                                                     .WWWWWWWWWWW
#             hhnn                                    :WWWWWWWWWWW
#         hBnnWWWWh                                   hWWWWWWWWWWW
#        .WWWBWWWWh                                  BWWWWWWWWWWWW
#        .WWWhWWWWh                                :WXXWWWWWWWWWWW
#        hWWWBWWWWWWh                             .XnXWWWWWWWBWWWW
#         WWWXWWWWWW:                             : hWWWWWWWWXWWWW
#        nWWWWXWWWWWWB:  :hhh:. ..                  XWWWWXnBhWWWWW
#        nWWWWBWWXhBBWWWWWWWWWWWWWW.                BWXXXXh hXWWWW
#        XWWWWBWWWWWWWWWWWWWWWWWWWBWWWBhn.              : .hXWh.BW
#        XWWWWWhWWWWWWWWWWBWWWWWXWBWWWWWWWWhn          :h .nWWWn:n
#
#
#
#
#
#
#
#                                                               nX
#                                                              XWW
#                                                             :WWW
#                                                             BWWW
#                                                      :BXXXXXWWWW
#                                                      WWWWWWWWWWW
#                                                     .WWWWWWWWWWW
#             hhnn                                    :WWWWWWWWWWW
#         hBhnWWWWn                                   hWWWWWWWWWWW
#        .WWWBWWWWh                                 .BWWWWWWWWWWWW
#        .WWWhWWWWn                                :WBXWWWWWWWWWWW
#        BWWWBWWWWWWh                              XhXWWWWWWWBWWWW
#        .WWWBWWWWWW.                             : hWWWWWWWXXWWWW
#        hWWWWXWWWWWWhn..nhhh:. ..                  XWWWWXhXhWWWWW
#        hWWWWBWWXBBBWWWWWWWWWWWWWW.                hWXXXXB nXWWWW
#        BWWWWBWWWWWWWWWWWWWWWWWWWBWWWBhn.           .  .  hXWB:XW
#        WWWWWWBWWWWWWWWWWBWWWWWXBXWWWWWWWWhn          :h  :WWWn.n
#
#
#
#
#
#
#
#                                                               hX
#                                                              XWW
#                                                             nWWW
#                                                             BWWW
#                                                      :BXXXXXWWWW
#                                                      WWWWWWWWWWW
#                                                     .WWWWWWWWWWW
#             hhnn                                    nWWWWWWWWWWW
#         hBhnWWWWh                                   nWWWWWWWWWWW
#        .WWWBWWWWh                                 .BWWWWWWWWWWWW
#         WWWhWWWWh                                :WBWWWWWWWWWWWW
#        hWWWBWWWWWWh                             .XhXWWWWWWWhWWWW
#        .WWWXWWWWWW.                             : hWWWWWWWXXWWWW
#        hWWWWXWWWWWWBn..nhhh:. ..                  XWWWWXhXhWWWWW
#        hWWWWBWWXhBhWWWWWWWWWWWWWW.                BWXXXXB nXWWWW
#        BWWWWBWWWWWWWWWWWWWWWWWWWBWWWBhn.              :  BBWB:BW
#        XWWWWWBWWWWWWWWWWBWWWWWWXBWWWWWWWWBn          nn .:WWWn.n
#
#
#
#
#
#
#
#                                                               hX
#                                                              XWW
#                                                             :WWW
#                                                             BWWW
#                                                      :BXXXXXWWWW
#                                                      WWWWWWWWWWW
#                                                     .WWWWWWWWWWW
#             hhnn                                    nWWWWWWWWWWW
#         hBhnWWWWh                                   hWWWWWWWWWWW
#        .WWWBWWWWh                                 .XWWWWWWWWWWWW
#        .WWWhWWWWh                                :WBXWWWWWWWWWWW
#        BWWWBWWWWWWh                             .BhXWWWWWWWBWWWW
#        :WWWXWWWWWW.                             : nWWWWXWWWXWWWW
#        :WWWWXWWWWWWB: .nhhh:. ..                  XWWWWXnXhWWWWW
#        hWWWWBWWXhBhWWWWWWWWWWWWWW.                hWXXXXh nXWWWW
#        BWWWWXXWWWWWWWWWWWWWWWWWWXWWWBhn.              .  BXWB:XW
#        XWWWWWBWWWWWWWWWWBWWWWWWXXWWWWWWWWBn          :h .nWWW::n
#
#
#
#
#
#
#
#                                                               hX
#                                                              XWW
#                                                             nWWW
#                                                             hWWW
#                                                      :BBXXXXWWWW
#                                                      WWWWWWWWWWW
#                                                      WWWWWWWWWWW
#             hhnn                                    :WWWWWWWWWWW
#         hBhnWWWWn                                   hWWWWWWWWWWW
#        :WWWBWWWWn                                 .XWWWWWWWWWWWW
#        .WWWhXWWWn                                :WBXWWWWWWWWWWW
#        hWWWBWWWWWWh                             .XnXWWWWWWWXWWWW
#        :WWWXWWWWWW:                             : hWWWWXWWXWWWWW
#        hWWWWXWWWWWWBh:.nhhh:.  .                  XWWWWXnBhWWWWW
#        hWWWWBWWXBBBWWWWWWWWWWWWWW.                BWXXXBh nXWWWW
#        BWWWWXWWWWWWWWWWWWWWWWWWWBWWWBhn.              :  BXWh:XW
#        XWWWWWhWWWWWXWWWWXWWWWWXXBWWWWWWWWBn          :h .nWWWn:n
#
#
#
#
#
#
#
#                                                               hX
#                                                              XWW
#                                                             nWWW
#                                                             hWWW
#                                                      :BXXXXXWWWW
#                                                     .WWWWWWWWWWW
#                                                     .WWWWWWWWWWW
#             hhnn                                    nWWWWWWWWWWW
#         hBhnWWWWB                                   hWWWWWWWWWWW
#        .WWWBWWWWh                                 .XWWWWWWWWWWWW
#         XWWhXWWWh                                :WXWWWWWWWWWWWW
#        hWWWBWWWWWWB                             .XhXWWWWWWWXWWWW
#        .WWWXWWWWWW.                             n hWWWWWWWXXWWWW
#        nWWWWXWWWWWWBn::nhhh:. ..                  BWWWWXhBhWWWWW
#        BWWWWBWWXhBBWWWWWWWWWWWWWW                 BWXXXXh nXWWWW
#        BWWWWBXWWWWWWWWWWWWWWWWWWBWWWBhn.           .  .  BXWh:BW
#        WWWWWWhWWWWWWWWWWBWWWWWWBXWWWWWWWWBn          nn .:WWWn:h
#
#
#
#
#
#
#
#                                                               hX
#                                                              WWW
#                                                             nWWW
#                                                             BWWW
#                                                      :BBXXXXWWWW
#                                                      WWWWWWWWWWW
#                                                     :WWWWWWWWWWW
#             hhnn                                    nWWWWWWWWWWW
#         hBhnWWWWn                                   nWWWWWWWWWWW
#        .WWWBWWWWn                                 .XWWWWWWWWWWWW
#        .WWWhWWWWh                                :WBXWWWWWWWWWWW
#        hWWWBWWWWWWh                             .XnXWWWWWWWXWWWW
#        .WWWXWWWWWW.                             : hWWWXXWWXWWWWW
#        :WWWWXWWWWWWBn:.nhhh:. .                   BWWWWXnBhWWWWW
#        hWWWWBWWXhhBWWWWWWWWWWWWWW.                BWXXXXh hXWWWW
#        BWWWWBWWWWWWWWWWWWWWWWWWWBWWWBnn.           .  n  BXWB:XW
#        WWWWWWhWWWWWWWWWWXXWWWWXXXWWWWWWWWh:          nh  nWWWn.n
#
#
#
#
#
#
#
#                                                               hX
#                                                              BWW
#                                                             nWWW
#                                                             hWWW
#                                                      :BXXXXXWWWW
#                                                      WWWWWWWWWWW
#                                                     :WWWWWWWWWWW
#             hhnn                                    nWWWWWWWWWWW
#         hBhnWWWWn                                   nWWWWWWWWWWW
#        .WWWBWWWWh                                 .WWWWWWWWWWWWW
#         WWWBWWWWh                                :WXXWWWWWWWWWWW
#        hWWWBWWWWWWh                             .XnXWWWWWWWBWWWW
#        .WWWXWWWWWW.                             : hWWWWWWWXXWWWW
#        hWWWWXWWWWWWXhn:hhhh:. ..                  XWWWWXnBhWWWWW
#        hWWWWBWWXBBXWWWWWWWWWWWWWW.                hWXXWXn hXXWWW
#        XWWWWXXWWWWWWWWWWWWWWWWWWBWWWBhn.           .  .BhhWhnnhX
#        WWWWWWBXWWWWWWWWWBXWWWWXWXWWWWWWWWhn.          nh hW  XWW
#
#
#
#
#
#
#
#                                                               hX
#                                                              XWW
#                                                             nWWW
#                                                             BWWW
#                                                      :BXXXXXWWWW
#                                                      WWWWWWWWWWW
#                                                     .WWWWWWWWWWW
#             hhnn                                    nWWWWWWWWWWW
#         hBhnWWWWh                                   hWWWWWWWWWWW
#        .WWWBWWWWh                                 .XWWWWWWWWWWWW
#         WWWBWWWWh                                :WBWWWWWWWWWWWW
#        hWWWBWWWWWWh                             .XhXWWWWWWWBWWWW
#        :WWWXWWWWWW.                             : hWWWWWWWXWWWWW
#        nWWWWXWWWWWWBhn.nhhh:. ..                  BWWWWXnBhWWWWW
#        nWWWWBWXXhBBWWWWWWWWWWWWWW.                BWXXWXh nWXWWW
#        BWWWWBWWWWWWWWWWWWWWWWWWWXWWWBhn.          n:  .BhBWWhBhW
#        XWWWWWhWWWWWWWWWWXWWWWWWXBWWWWWWWWhn:          :h nWh :XX
#
#
#
#
#
#
#
#                                                               hX
#                                                              WWW
#                                                             nWWW
#                                                             BWWW
#                                                      :BBXXXXWWWW
#                                                      WWWWWWWWWWW
#                                                     .WWWWWWWWWWW
#             hhnn                                    nWWWWWWWWWWW
#         hBhnWWWWh                                   hWWWWWWWWWWW
#        .WWWBWWWWn                                  XWWWWWWWWWWWW
#        .XWWhWWWWh                                :WBWWWWWWWWWWWW
#        hWWWBWWWWWWh                             .BhXWWWWWWWBWWWW
#        nWWWXWWWWWW.                             : hWWWWWWWXXWWWW
#        nWWWWXWWWWWWXh:.:hhh:. ..                  XWWWWWnXhWWWWW
#        hWWWWBWXXhBBWWWWWWWWWWWWWW.                BWXWWXh hWXWWW
#        BWWWWXWWWWWWWWWWWWWWWWWWWBWWWBhn.          n:   nhBWWhBhW
#        WWWWWWhWWWWWWWWWWXWWWWWWXBWWWWWWWWBn:          .h.nWX nWB
#
#
#
#
#
#
#
#                                                               hX
#                                                              XWW
#                                                             nWWW
#                                                             BWWW
#                                                      :BXXXXXWWWW
#                                                      WWWWWWWWWWW
#                                                     .WWWWWWWWWWW
#             hhnn                                    :WWWWWWWWWWW
#         hBhnWWWWh                                   hWWWWWWWWWWW
#        :WWWBWWWWh                                 .XWWWWWWWWWWWW
#        .WWWBWWWWn                                :WBWWWWWWWWWWWW
#        hWWWhWWWWWWh                             .XhXWWWWWWWBWWWW
#        :WWWXWWWWWW.                             n hWWWWWWWXXWWWW
#        nWWWWXWWWWWWBnn:nhhh:. ..                  BWWWWXnXhWWWWW
#        BWWWWBWXXhBhWWWWWWWWWWWWWW.                BWXXWBh hWXWWW
#        XWWWWXWWWWWWWWWWWWWWWWWWWBWWWBh:.          n:   BhBWWBBhW
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21640/4188105013.py in <module>
#      12                 dist = depth.get_distance(x, y)
#      13                 if 0 < dist and dist < 1:
# ---> 14                     coverage[int(x/10)] += 1
#      15
#      16             if y%20 is 19:
#
# KeyboardInterrupt:
